# %% [markdown]
# ## Assignment 7
#
# This assignment requires you to work with selenium, BeautifullSoup and possibly regular expressions
#
# The next couple of weeks we are going to ask you: the students to create the assignment. The plan is for every group, to find a suitable website and create a a question to ask about the data on the site.
# These questions should be available to everyone thursday at 8:30 here: https://docs.google.com/spreadsheets/d/1sxKJcpXv_pm85o-XCNxnoSg28xmDeqyGKA_I_9ILkeg/edit?usp=sharing
#
# Then for the weekly assignment you can choose between the different exercises presented on the specific week.
#
# ### Fallback plan
# If this plan has some startup trouble, I have made a backup exercise below that you can choose if you cant find a suitable exercise on the google sheet.
#
# Hand-in:
# * All the code in a .py file

# %% [markdown]
# ### Part 1: Preparing data
#
# - Use selenium to go to dba.dk with any search phrase
# - Find all products added today
# - Find only those from 'København og omegn'
# - create a .py file containing above function as a module that will return the browser page source.

# %%
## DONT RUN THE CODE WE CANT FIX REQUIREMENTS.TXT SO CODE WONT RUN GG
import mypy

page_source = mypy.get_page_source('https://www.dba.dk')
mypy.save_to_file(page_source)

# %% [markdown]
# ### Part 2: Extracting the data
#
# - Use BeautifulSoup to extract all the products in a different function in the module (see selenium_krak.py for example)
# - Make a list with tuples of description, year (if available), price, image url and url to details page.
# - Sort the products by price
# - Return an html table with all the data

# %%
## DONT RUN THE CODE WE CANT FIX REQUIREMENTS.TXT SO CODE WONT RUN GG
# !python mypy.py
# Out:
# List items sorted by price:
#
# 90
# Vinterjakke, Vinterjakke, Molo, str. 110
# https://i.ebayimg.com/images/g/sFYAAOSwuAVcndLG/s-l200.jpg
# https://www.dba.dk/vinterjakke-vinterjakke/id-1054107730/
#
#
# 100
# Jakke, Jakke, Wheat, str. 152, Flot  sort  vinterjakke  brugt lidt. Fast pris plus fragt
# https://i.ebayimg.com/images/g/9qEAAOSwu4Jcnc0J/s-l200.jpg
# https://www.dba.dk/jakke-jakke-wheat-str-1/id-1054107101/
#
#
# 199
# Vinterjakke, str. L, Just Junkies, Rigtig fed Just Junkies vinterjakke, sælges da den desværre er for stor. Jakken er i størrelse L
# https://i.ebayimg.com/images/g/1zQAAOSwWylcnhVT/s-l200.jpg
# https://www.dba.dk/vinterjakke-str-l-just/id-1054114961/
#
#
# 250
# Vinterjakke, Vinterjakke, Mini A Ture, str. 128
# https://i.ebayimg.com/images/g/cwwAAOSwY8NcneYh/s-l200.jpg
# https://www.dba.dk/vinterjakke-vinterjakke-mini/id-1054109823/
#
#
# 250
# Dynejakke, str. L, Timberland, Timberland dunjakke / dynejakke / vinterjakke i str. Large. Jeg er selv 1.89 cm. og normal af bygning. Godt brugt, men stadig funktionel :)
# https://i.ebayimg.com/images/g/UVQAAOSwKgtcncl0/s-l200.jpg
# https://www.dba.dk/dynejakke-str-l-timberla/id-1054106757/
#
#
# 250
# Vinterjakke, str. XL, BLACKBLUE,  Grå,  Uld 50% / acryl 50%,  Næsten som ny, Med dobbeltradet !
# Kommer fra ikke ryge og dyrfrit lejlighed !
# Model:Sømandsfrakke !
# L: 95 cm !
# To lommer og to inderlommer !
# Ny pris:999 kr !
# Kan godt sende over GLS ( 49 kr) !
# Har mobilpay ( 41 44 58 41 ) !
# Fast Pris !
# https://i.ebayimg.com/images/g/ayUAAOSwHu9cnR9Y/s-l200.jpg
# https://www.dba.dk/vinterjakke-str-xl/id-1054099723/
#
#
# 300
# Vinterjakke, Vinterjakke med aftagelig hætte, HUMMEL, str. 104, Fin jakke i størrelsen 104 med ganske få brugsspor.
#
# 300,- eller kom med et bud.
#
# Kan sendes for 35,-
# https://i.ebayimg.com/images/g/KQAAAOSwjlBcnfDi/s-l200.jpg
# https://www.dba.dk/vinterjakke-vinterjakke-med/id-1054110969/
#
#
# 300
# Vinterjakke, str. 40, Part Two str 40,  Sort,  ----,  God men brugt, Flot varm vinterjakke Part Two str 40. Brugt men god. Kan leveres i Kbh. Mobil 53781221
# https://i.ebayimg.com/images/g/dUUAAOSwLqRcnaCI/s-l200.jpg
# https://www.dba.dk/vinterjakke-str-40-part-two/id-1054104536/
#
#
# 350
# Vinterjakke, Vinterjakke, Molo, str. 122, Ubrugt. Absolut ingen fejl mv. Sendes gerne ??
# https://i.ebayimg.com/images/g/AisAAOSwyZhcnPiy/s-l200.jpg
# https://www.dba.dk/vinterjakke-vinterjakke/id-1054094972/
#
#
# 400
# Vinterjakke, str. 40, Vila ,  Næsten som ny, Str L
# https://i.ebayimg.com/images/g/C14AAOSwQtJcng90/s-l200.jpg
# https://www.dba.dk/vinterjakke-str-40-vila/id-1054114294/
#
#
# 400
# Vinterjakke, str. XL, Dolomite,  God men brugt
# https://i.ebayimg.com/images/g/URMAAOSwO-ZcnRFA/s-l200.jpg
# https://www.dba.dk/vinterjakke-str-xl/id-1054097744/
#
#
# 450
# Jakke, str. 40, Geographical Norway,  Sort,  Næsten som ny, Sælger denne dame vinterjakke da med bedre halvdel har fået en ny i gave.
#
# Den er næsten ikke brugt, da min kone synes den er for varm! Mange gode lommer bla. flere håndvarme lommer og en stor lomme bagpå til ting som halstørklæder.
# https://i.ebayimg.com/images/g/FOUAAOSw6hZcnOgu/s-l200.jpg
# https://www.dba.dk/jakke-str-40-geographical/id-1054092866/
#
#
# 500
# Vinterfrakke, str. M, Columbia,  Mørkegrøn, Vinterjakke, str. M, Columbia, Mørkegrøn
# https://i.ebayimg.com/images/g/fwEAAOSwrL9cnOhg/s-l200.jpg
# https://www.dba.dk/vinterfrakke-str-m/id-1054092664/
#
#
# 600
# Vinterjakke, str. L, Wesc,  Rød,  Ubrugt
# https://i.ebayimg.com/images/g/IbYAAOSwTgJcnSn9/s-l200.jpg
# https://www.dba.dk/vinterjakke-str-l-wesc/id-1054100940/
#
#
# 699
# Vinterjakke, str. S, Helly Hansen, Sælger min Helly Hansen Anniversary vinter jakke da den desværre er blevet for lille. Den er dog rigtig varm, og vandtæt. Den er købt i Helly Hansen butikken i Fields. Kom gerne med bud.
# https://i.ebayimg.com/images/g/kzcAAOSwPHZcnheK/s-l200.jpg
# https://www.dba.dk/vinterjakke-str-s-helly/id-1054115179/
#
#
# 900
# Vindjakke, str. findes i flere str., The North Face ,  Sort ,  .,  Næsten som ny, Stort set ny North Face vinterjakke str L sælges da jeg desværre fik købt den for stor til mig..billerne driller med farven den er på ingen måde falmet eller andet i farven...så helt sort..
# https://i.ebayimg.com/images/g/Ee0AAOSwBPxcnQ8D/s-l200.jpg
# https://www.dba.dk/vindjakke-str-findes-i-flere/id-1054097791/
#
#
# 1500
# Vinterjakke, str. 38, Rock and blue,  Sort,  God men brugt, Har denne super lækre Rock and Blue Beam 2017 model til salg.
# Prisen er grundet hul i det ene ærme, som selvfølgelig er blevet syet, dog har det ingen betydning for jakken.
# https://i.ebayimg.com/images/g/m14AAOSwTkFcnhY7/s-l200.jpg
# https://www.dba.dk/vinterjakke-str-38-rock-and/id-1054115083/
#
#
# 2100
# Vinterjakke, str. L, HUGO BOSS,  Sort,  Dun,  Ubrugt, Brugt 6 gange i vinteren Sælges da den er lidt for stor til mig selv Lækker jakke købt for 3 måneder siden til lidt under 4000kr
#
# Afhentes i kbh
# https://i.ebayimg.com/images/g/KdkAAOSwf-BcnhXr/s-l200.jpg
# https://www.dba.dk/vinterjakke-str-l-hugo/id-1054114943/
#
#
# 6000
# Dynejakke, str. L, Moncler,  Konge blå,  Næsten som ny, Moncler vinterjakke sælges.
# Købt i Moncler butik hvor nyprisen var 13.000 kr.
# Brugt 2 vintre og altid passet og plejet, derfor den gode stand af jakken. Hætten kan knappes af.
# https://i.ebayimg.com/images/g/PicAAOSwqaNcnPLi/s-l200.jpg
# https://www.dba.dk/dynejakke-str-l-moncler/id-1054094293/

# %% [markdown]
# ### Part 3:
# - Add functionality to get the phone number for each product.
